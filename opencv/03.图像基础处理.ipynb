# %%
import numpy as np
import cv2 as cv
import matplotlib.pyplot as plt

# %%
img = np.zeros((256,256,3),np.uint8)

# %%
plt.imshow(img[:,:,::-1])

# %%
img[100,100]
# Out:
# array([0, 0, 0], dtype=uint8)

# %%
img[100,100,0]
# Out:
# 0

# %%
img[100,100] = (0,0,255)

# %%
plt.imshow(img[:,:,::-1])

# %%
img[100,100]
# Out:
# array([  0,   0, 255], dtype=uint8)

# %%
img.shape
# Out:
# (256, 256, 3)

# %%
img.dtype
# Out:
# dtype('uint8')

# %%
img.size
# Out:
# 196608

# %%
dili = cv.imread("./image/dili.jpg")

# %%
plt.imshow(dili[:,:,::-1])

# %%
b,g,r = cv.split(dili)

# %%
plt.imshow(b,cmap=plt.cm.gray)

# %%
img2 = cv.merge((b,g,r))

# %%
plt.imshow(img2[:,:,::-1])

# %%
gray = cv.cvtColor(dili,cv.COLOR_BGR2GRAY)

# %%
plt.imshow(gray,cmap=plt.cm.gray)

# %%
hsv = cv.cvtColor(dili,cv.COLOR_BGR2HSV)

# %%
plt.imshow(hsv)

# %%
import tensorflow as tf
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-22-64156d691fe5> in <module>
# ----> 1 import tensorflow as tf
#
# ModuleNotFoundError: No module named 'tensorflow'

# %%
c = tf.constant([[4.,5.],[10.,1.]])

# %%
c

# %%
tf.argmax(c,axis=0)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-23-41a8a7899aec> in <module>
# ----> 1 tf.argmax(c,axis=0)
#
# NameError: name 'tf' is not defined

# %%
tf.argmin(c,0)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-24-83e1cedfe27b> in <module>
# ----> 1 tf.argmin(c,0)
#
# NameError: name 'tf' is not defined

# %%
tf.argmax(c)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-25-7eb4aecf0343> in <module>
# ----> 1 tf.argmax(c)
#
# NameError: name 'tf' is not defined

# %%
tf.__version__
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-26-65996cac02ec> in <module>
# ----> 1 tf.__version__
#
# NameError: name 'tf' is not defined

# %%
tf.reduce_max(c)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-27-c170fb9fee41> in <module>
# ----> 1 tf.reduce_max(c)
#
# NameError: name 'tf' is not defined

# %%
tf.reduce_min(c)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-28-f8e20b7974d4> in <module>
# ----> 1 tf.reduce_min(c)
#
# NameError: name 'tf' is not defined

# %%
tf.argmin(c)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-29-5e469d3998d4> in <module>
# ----> 1 tf.argmin(c)
#
# NameError: name 'tf' is not defined

# %%
c
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-30-2b66fd261ee5> in <module>
# ----> 1 c
#
# NameError: name 'c' is not defined

# %%
c = tf.constant([[4.,5.],[3.,1.]])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-31-1d0443b287f4> in <module>
# ----> 1 c = tf.constant([[4.,5.],[3.,1.]])
#
# NameError: name 'tf' is not defined

# %%
tf.argmax(c,1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-32-15d4ecbd2c3a> in <module>
# ----> 1 tf.argmax(c,1)
#
# NameError: name 'tf' is not defined

# %%
c
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-33-2b66fd261ee5> in <module>
# ----> 1 c
#
# NameError: name 'c' is not defined

# %%
argmin()方法在没有指定维度时，默认返回的是第0维度列中最小值的索引
# Out:
#   File "<ipython-input-34-4d650ee383ad>", line 1
#     argmin()方法在没有指定维度时，默认返回的是第0维度列中最小值的索引
#                                         ^
# SyntaxError: invalid character in identifier
